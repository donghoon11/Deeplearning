# %% [markdown]
# #### ResNet18 모델 정의 및 인스턴스 초기화

# %%
import torch
import torch.nn as nn
import torch.nn.functional as F
import torch.backends.cudnn as cudnn
import torch.optim as optim
import os


# ResNet18을 위해 최대한 간단히 수정한 BasicBlock 클래스 정의
class BasicBlock(nn.Module):
    def __init__(self, in_planes, planes, stride=1):
        super(BasicBlock, self).__init__()

        # 3x3 필터를 사용 (너비와 높이를 줄일 때는 stride 값 조절)
        self.conv1 = nn.Conv2d(in_planes, planes, kernel_size=3, stride=stride, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(planes) # 배치 정규화(batch normalization)

        # 3x3 필터를 사용 (패딩을 1만큼 주기 때문에 너비와 높이가 동일)
        self.conv2 = nn.Conv2d(planes, planes, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn2 = nn.BatchNorm2d(planes) # 배치 정규화(batch normalization)

        self.shortcut = nn.Sequential() # identity인 경우
        if stride != 1: # stride가 1이 아니라면, Identity mapping이 아닌 경우
            self.shortcut = nn.Sequential(
                nn.Conv2d(in_planes, planes, kernel_size=1, stride=stride, bias=False),
                nn.BatchNorm2d(planes)
            )

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.bn2(self.conv2(out))
        out += self.shortcut(x) # (핵심) skip connection
        out = F.relu(out)
        return out


# ResNet 클래스 정의
class ResNet(nn.Module):
    def __init__(self, block, num_blocks, num_classes=10):
        super(ResNet, self).__init__()
        self.in_planes = 64

        # 64개의 3x3 필터(filter)를 사용
        self.conv1 = nn.Conv2d(3, 64, kernel_size=3, stride=1, padding=1, bias=False)
        self.bn1 = nn.BatchNorm2d(64)
        self.layer1 = self._make_layer(block, 64, num_blocks[0], stride=1)
        self.layer2 = self._make_layer(block, 128, num_blocks[1], stride=2)
        self.layer3 = self._make_layer(block, 256, num_blocks[2], stride=2)
        self.layer4 = self._make_layer(block, 512, num_blocks[3], stride=2)
        self.linear = nn.Linear(512, num_classes)

    def _make_layer(self, block, planes, num_blocks, stride):
        strides = [stride] + [1] * (num_blocks - 1)
        layers = []
        for stride in strides:
            layers.append(block(self.in_planes, planes, stride))
            self.in_planes = planes # 다음 레이어를 위해 채널 수 변경
        return nn.Sequential(*layers)

    def forward(self, x):
        out = F.relu(self.bn1(self.conv1(x)))
        out = self.layer1(out)
        out = self.layer2(out)
        out = self.layer3(out)
        out = self.layer4(out)
        out = F.avg_pool2d(out, 4)
        out = out.view(out.size(0), -1)
        out = self.linear(out)
        return out


# ResNet18 함수 정의
def ResNet18():
    return ResNet(BasicBlock, [2, 2, 2, 2])

# %% [markdown]
# #### 데이터셋(Dataset) 다운로드 및 불러오기

# %%
import torchvision
import torchvision.transforms as transforms

transform_train = transforms.Compose([
    transforms.RandomCrop(32, padding=4),
    transforms.RandomHorizontalFlip(),
    transforms.ToTensor(),
])

transform_test = transforms.Compose([
    transforms.ToTensor(),
])

train_dataset = torchvision.datasets.CIFAR10(root='./data', train=True, download=True, transform=transform_train)
test_dataset = torchvision.datasets.CIFAR10(root='./data', train=False, download=True, transform=transform_test)

train_loader = torch.utils.data.DataLoader(train_dataset, batch_size=128, shuffle=True, num_workers=4)
test_loader = torch.utils.data.DataLoader(test_dataset, batch_size=100, shuffle=False, num_workers=4)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ./data/cifar-10-python.tar.gz
#   0%|          | 0/170498071 [00:00<?, ?it/s]
# Extracting ./data/cifar-10-python.tar.gz to ./data
# Files already downloaded and verified
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))

# %% [markdown]
# #### 환경 설정 및 학습(Training) 함수 정의

# %%
device = 'cuda'

net = ResNet18()
net = net.to(device)
net = torch.nn.DataParallel(net)
cudnn.benchmark = True

learning_rate = 0.1
file_name = 'resnet18_cifar10.pt'

criterion = nn.CrossEntropyLoss()
optimizer = optim.SGD(net.parameters(), lr=learning_rate, momentum=0.9, weight_decay=0.0002)


def train(epoch):
    print('\n[ Train epoch: %d ]' % epoch)
    net.train()
    train_loss = 0
    correct = 0
    total = 0
    for batch_idx, (inputs, targets) in enumerate(train_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        optimizer.zero_grad()

        benign_outputs = net(inputs)
        loss = criterion(benign_outputs, targets)
        loss.backward()

        optimizer.step()
        train_loss += loss.item()
        _, predicted = benign_outputs.max(1)

        total += targets.size(0)
        correct += predicted.eq(targets).sum().item()
        
        if batch_idx % 100 == 0:
            print('\nCurrent batch:', str(batch_idx))
            print('Current benign train accuracy:', str(predicted.eq(targets).sum().item() / targets.size(0)))
            print('Current benign train loss:', loss.item())

    print('\nTotal benign train accuarcy:', 100. * correct / total)
    print('Total benign train loss:', train_loss)


def test(epoch):
    print('\n[ Test epoch: %d ]' % epoch)
    net.eval()
    loss = 0
    correct = 0
    total = 0

    for batch_idx, (inputs, targets) in enumerate(test_loader):
        inputs, targets = inputs.to(device), targets.to(device)
        total += targets.size(0)

        outputs = net(inputs)
        loss += criterion(outputs, targets).item()

        _, predicted = outputs.max(1)
        correct += predicted.eq(targets).sum().item()

    print('\nTest accuarcy:', 100. * correct / total)
    print('Test average loss:', loss / total)

    state = {
        'net': net.state_dict()
    }
    if not os.path.isdir('checkpoint'):
        os.mkdir('checkpoint')
    torch.save(state, './checkpoint/' + file_name)
    print('Model Saved!')


def adjust_learning_rate(optimizer, epoch):
    lr = learning_rate
    if epoch >= 100:
        lr /= 10
    if epoch >= 150:
        lr /= 10
    for param_group in optimizer.param_groups:
        param_group['lr'] = lr

# %% [markdown]
# #### 학습(Training) 진행

# %% [markdown]
# * 대략 20번의 epoch 이후에도 85%가량의 test accuracy를 얻을 수 있습니다.

# %%
# for epoch in range(0, 200):
for epoch in range(0, 20):
    adjust_learning_rate(optimizer, epoch)
    train(epoch)
    test(epoch)
# Out:
# [ Train epoch: 0 ]
# /usr/local/lib/python3.7/dist-packages/torch/utils/data/dataloader.py:490: UserWarning: This DataLoader will create 4 worker processes in total. Our suggested max number of worker in current system is 2, which is smaller than what this DataLoader is going to create. Please be aware that excessive worker creation might get DataLoader running slow or even freeze, lower the worker number to avoid potential slowness/freeze if necessary.
#   cpuset_checked))
# Current batch: 0
# Current benign train accuracy: 0.109375
# Current benign train loss: 2.408104181289673
#
# Current batch: 100
# Current benign train accuracy: 0.2734375
# Current benign train loss: 1.984822154045105
#
# Current batch: 200
# Current benign train accuracy: 0.3515625
# Current benign train loss: 1.8484381437301636
#
# Current batch: 300
# Current benign train accuracy: 0.375
# Current benign train loss: 1.6492489576339722
#
# Total benign train accuarcy: 29.444
# Total benign train loss: 781.5355565547943
#
# [ Test epoch: 0 ]
#
# Test accuarcy: 41.1
# Test average loss: 0.015911566913127898
# Model Saved!
#
# [ Train epoch: 1 ]
#
# Current batch: 0
# Current benign train accuracy: 0.46875
# Current benign train loss: 1.528527021408081
#
# Current batch: 100
# Current benign train accuracy: 0.4296875
# Current benign train loss: 1.505066156387329
#
# Current batch: 200
# Current benign train accuracy: 0.421875
# Current benign train loss: 1.494367003440857
#
# Current batch: 300
# Current benign train accuracy: 0.4609375
# Current benign train loss: 1.4461731910705566
#
# Total benign train accuarcy: 43.872
# Total benign train loss: 599.0596972703934
#
# [ Test epoch: 1 ]
#
# Test accuarcy: 49.48
# Test average loss: 0.01399976761341095
# Model Saved!
#
# [ Train epoch: 2 ]
#
# Current batch: 0
# Current benign train accuracy: 0.53125
# Current benign train loss: 1.314640998840332
#
# Current batch: 100
# Current benign train accuracy: 0.5390625
# Current benign train loss: 1.2669708728790283
#
# Current batch: 200
# Current benign train accuracy: 0.5859375
# Current benign train loss: 1.2941248416900635
#
# Current batch: 300
# Current benign train accuracy: 0.65625
# Current benign train loss: 1.1213696002960205
#
# Total benign train accuarcy: 53.516
# Total benign train loss: 504.0314940214157
#
# [ Test epoch: 2 ]
#
# Test accuarcy: 56.49
# Test average loss: 0.012160705786943435
# Model Saved!
#
# [ Train epoch: 3 ]
#
# Current batch: 0
# Current benign train accuracy: 0.5859375
# Current benign train loss: 1.2721552848815918
#
# Current batch: 100
# Current benign train accuracy: 0.609375
# Current benign train loss: 0.982808530330658
#
# Current batch: 200
# Current benign train accuracy: 0.6015625
# Current benign train loss: 1.1703763008117676
#
# Current batch: 300
# Current benign train accuracy: 0.5625
# Current benign train loss: 1.1992216110229492
#
# Total benign train accuarcy: 60.99
# Total benign train loss: 428.07315343618393
#
# [ Test epoch: 3 ]
#
# Test accuarcy: 40.13
# Test average loss: 0.02049013143777847
# Model Saved!
#
# [ Train epoch: 4 ]
#
# Current batch: 0
# Current benign train accuracy: 0.703125
# Current benign train loss: 0.8557255268096924
#
# Current batch: 100
# Current benign train accuracy: 0.6171875
# Current benign train loss: 1.1769288778305054
#
# Current batch: 200
# Current benign train accuracy: 0.6953125
# Current benign train loss: 0.817112922668457
#
# Current batch: 300
# Current benign train accuracy: 0.71875
# Current benign train loss: 0.8269435167312622
#
# Total benign train accuarcy: 67.136
# Total benign train loss: 364.2851818203926
#
# [ Test epoch: 4 ]
#
# Test accuarcy: 64.68
# Test average loss: 0.010211445528268814
# Model Saved!
#
# [ Train epoch: 5 ]
#
# Current batch: 0
# Current benign train accuracy: 0.6640625
# Current benign train loss: 0.9289244413375854
#
# Current batch: 100
# Current benign train accuracy: 0.703125
# Current benign train loss: 0.7764304876327515
#
# Current batch: 200
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.6518775820732117
#
# Current batch: 300
# Current benign train accuracy: 0.75
# Current benign train loss: 0.7412310838699341
#
# Total benign train accuarcy: 72.0
# Total benign train loss: 310.8888422846794
#
# [ Test epoch: 5 ]
#
# Test accuarcy: 69.05
# Test average loss: 0.008987442368268967
# Model Saved!
#
# [ Train epoch: 6 ]
#
# Current batch: 0
# Current benign train accuracy: 0.6953125
# Current benign train loss: 0.9437622427940369
#
# Current batch: 100
# Current benign train accuracy: 0.7421875
# Current benign train loss: 0.7926095724105835
#
# Current batch: 200
# Current benign train accuracy: 0.71875
# Current benign train loss: 0.7641252279281616
#
# Current batch: 300
# Current benign train accuracy: 0.7734375
# Current benign train loss: 0.6878664493560791
#
# Total benign train accuarcy: 75.918
# Total benign train loss: 267.95689302682877
#
# [ Test epoch: 6 ]
#
# Test accuarcy: 73.89
# Test average loss: 0.007798934805393219
# Model Saved!
#
# [ Train epoch: 7 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.5562641024589539
#
# Current batch: 100
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.5215712785720825
#
# Current batch: 200
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.4853471517562866
#
# Current batch: 300
# Current benign train accuracy: 0.7421875
# Current benign train loss: 0.659567654132843
#
# Total benign train accuarcy: 79.098
# Total benign train loss: 235.86815810203552
#
# [ Test epoch: 7 ]
#
# Test accuarcy: 74.75
# Test average loss: 0.0075803251624107365
# Model Saved!
#
# [ Train epoch: 8 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.5189968943595886
#
# Current batch: 100
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.5678209066390991
#
# Current batch: 200
# Current benign train accuracy: 0.75
# Current benign train loss: 0.7175940275192261
#
# Current batch: 300
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.36588260531425476
#
# Total benign train accuarcy: 81.158
# Total benign train loss: 212.83073341846466
#
# [ Test epoch: 8 ]
#
# Test accuarcy: 79.21
# Test average loss: 0.006215993303060532
# Model Saved!
#
# [ Train epoch: 9 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.5217366814613342
#
# Current batch: 100
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.5385220050811768
#
# Current batch: 200
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.4387490749359131
#
# Current batch: 300
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.47881969809532166
#
# Total benign train accuarcy: 82.704
# Total benign train loss: 194.7332659959793
#
# [ Test epoch: 9 ]
#
# Test accuarcy: 78.88
# Test average loss: 0.00617865236401558
# Model Saved!
#
# [ Train epoch: 10 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8046875
# Current benign train loss: 0.5284386873245239
#
# Current batch: 100
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.5028772950172424
#
# Current batch: 200
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.4981559216976166
#
# Current batch: 300
# Current benign train accuracy: 0.8515625
# Current benign train loss: 0.4539692997932434
#
# Total benign train accuarcy: 84.128
# Total benign train loss: 179.45867395401
#
# [ Test epoch: 10 ]
#
# Test accuarcy: 82.27
# Test average loss: 0.00530629734992981
# Model Saved!
#
# [ Train epoch: 11 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.437285840511322
#
# Current batch: 100
# Current benign train accuracy: 0.78125
# Current benign train loss: 0.5539208054542542
#
# Current batch: 200
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.5214917063713074
#
# Current batch: 300
# Current benign train accuracy: 0.84375
# Current benign train loss: 0.4063989520072937
#
# Total benign train accuarcy: 84.982
# Total benign train loss: 169.28792367875576
#
# [ Test epoch: 11 ]
#
# Test accuarcy: 80.65
# Test average loss: 0.005673501446843148
# Model Saved!
#
# [ Train epoch: 12 ]
#
# Current batch: 0
# Current benign train accuracy: 0.859375
# Current benign train loss: 0.44874483346939087
#
# Current batch: 100
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.47130119800567627
#
# Current batch: 200
# Current benign train accuracy: 0.921875
# Current benign train loss: 0.29238462448120117
#
# Current batch: 300
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.36643186211586
#
# Total benign train accuarcy: 85.794
# Total benign train loss: 158.25362452864647
#
# [ Test epoch: 12 ]
#
# Test accuarcy: 82.6
# Test average loss: 0.005204017758369445
# Model Saved!
#
# [ Train epoch: 13 ]
#
# Current batch: 0
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.33772847056388855
#
# Current batch: 100
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.314971387386322
#
# Current batch: 200
# Current benign train accuracy: 0.875
# Current benign train loss: 0.38189005851745605
#
# Current batch: 300
# Current benign train accuracy: 0.796875
# Current benign train loss: 0.5846670269966125
#
# Total benign train accuarcy: 86.858
# Total benign train loss: 148.25671355426311
#
# [ Test epoch: 13 ]
#
# Test accuarcy: 81.93
# Test average loss: 0.005737861210107803
# Model Saved!
#
# [ Train epoch: 14 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.25663620233535767
#
# Current batch: 100
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.37878528237342834
#
# Current batch: 200
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.367783784866333
#
# Current batch: 300
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.3564206063747406
#
# Total benign train accuarcy: 87.608
# Total benign train loss: 139.6870465129614
#
# [ Test epoch: 14 ]
#
# Test accuarcy: 82.84
# Test average loss: 0.005099878218770027
# Model Saved!
#
# [ Train epoch: 15 ]
#
# Current batch: 0
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.29585209488868713
#
# Current batch: 100
# Current benign train accuracy: 0.828125
# Current benign train loss: 0.4301396906375885
#
# Current batch: 200
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.47510457038879395
#
# Current batch: 300
# Current benign train accuracy: 0.8359375
# Current benign train loss: 0.4636556804180145
#
# Total benign train accuarcy: 88.224
# Total benign train loss: 135.7617488950491
#
# [ Test epoch: 15 ]
#
# Test accuarcy: 85.49
# Test average loss: 0.004535108825564385
# Model Saved!
#
# [ Train epoch: 16 ]
#
# Current batch: 0
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.2791706621646881
#
# Current batch: 100
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.1897580921649933
#
# Current batch: 200
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.31737011671066284
#
# Current batch: 300
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.27635371685028076
#
# Total benign train accuarcy: 88.488
# Total benign train loss: 129.96498429775238
#
# [ Test epoch: 16 ]
#
# Test accuarcy: 81.56
# Test average loss: 0.005734161818027496
# Model Saved!
#
# [ Train epoch: 17 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8671875
# Current benign train loss: 0.4683890640735626
#
# Current batch: 100
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.37012431025505066
#
# Current batch: 200
# Current benign train accuracy: 0.9140625
# Current benign train loss: 0.24699324369430542
#
# Current batch: 300
# Current benign train accuracy: 0.890625
# Current benign train loss: 0.29622504115104675
#
# Total benign train accuarcy: 88.728
# Total benign train loss: 127.6816436946392
#
# [ Test epoch: 17 ]
#
# Test accuarcy: 81.34
# Test average loss: 0.005703185790777206
# Model Saved!
#
# [ Train epoch: 18 ]
#
# Current batch: 0
# Current benign train accuracy: 0.875
# Current benign train loss: 0.2909814715385437
#
# Current batch: 100
# Current benign train accuracy: 0.875
# Current benign train loss: 0.35009369254112244
#
# Current batch: 200
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.30061495304107666
#
# Current batch: 300
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.26314887404441833
#
# Total benign train accuarcy: 89.174
# Total benign train loss: 122.5363294929266
#
# [ Test epoch: 18 ]
#
# Test accuarcy: 83.24
# Test average loss: 0.005243889856338501
# Model Saved!
#
# [ Train epoch: 19 ]
#
# Current batch: 0
# Current benign train accuracy: 0.8828125
# Current benign train loss: 0.3897208273410797
#
# Current batch: 100
# Current benign train accuracy: 0.8203125
# Current benign train loss: 0.5462389588356018
#
# Current batch: 200
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.2335515171289444
#
# Current batch: 300
# Current benign train accuracy: 0.8984375
# Current benign train loss: 0.2960442900657654
#
# Total benign train accuarcy: 89.426
# Total benign train loss: 118.81184165924788
#
# [ Test epoch: 19 ]
#
# Test accuarcy: 84.24
# Test average loss: 0.004829647973179817
# Model Saved!
